# %%
import time
import xlwt
import requests
from bs4 import BeautifulSoup
import random
import pandas as pd

# %%
headers = {
    "Accept": 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    "Accept-Encoding": 'gzip, deflate, br',
    "Accept-Language": 'zh-CN,zh;q=0.9',
    "Cache-Control": 'max-age=0',
    "Connection": 'keep-alive',
    "Cookie": '__mta=48482713.1635159163254.1635159163254.1635159163254.1; __mta=48482713.1635159163254.1635159163254.1636109843763.2; _lxsdk_cuid=17cb714c0e0c8-033e82611b0dc3-3a67410c-144000-17cb714c0e1c8; uuid_n_v=v1; uuid=9674BC503BCD11ECB4F8514365831FE83313CBD44FCA442B9EBF16166F870D9A; _lx_utm=utm_source%3DBaidu%26utm_medium%3Dorganic; _lxsdk=9674BC503BCD11ECB4F8514365831FE83313CBD44FCA442B9EBF16166F870D9A; _csrf=c0897c2fe8b12a6664d889f6c2bb4883c27ead5915e9e87f1ccc14fa38c974ad; Hm_lvt_703e94591e87be68cc8da0da7cbd0be2=1635159163,1635261061,1635851473,1636109833; Hm_lpvt_703e94591e87be68cc8da0da7cbd0be2=1636109844; _lxsdk_s=17cefbed57e-1bc-1b3-505%7C%7C4',
    "Host": 'www.maoyan.com',
    # sec-ch-ua: "Chromium";v="92", " Not A;Brand";v="99", "Google Chrome";v="92",
    "sec-ch-ua-mobile": '?0',
    "Sec-Fetch-Dest": 'document',
    "Sec-Fetch-Mode": 'navigate',
    "Sec-Fetch-Site": 'none',
    "Sec-Fetch-User": '?1',
    "Upgrade-Insecure-Requests": '1',
    "User-Agent": 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36',
}

# %%
url_list = []  # 所有单个url
for iii in range(0, 1):
	url = 'https://maoyan.com/board/4?offset=' + str(iii) + '0'
	response = requests.get(url, headers=headers).content.decode('utf-8')
	print(response)
	soup = BeautifulSoup(response, "lxml")
	# url
	listUrl = soup.select('.image-link')
	for i in listUrl:
		url_list.append('https://maoyan.com' + str(i['href']))
# 	time.sleep(random.randint(20, 50))
print(url_list)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Client Bad Request</title>
#     <link rel="stylesheet" href="https://imgcache.qq.com/qcloud/security/static/404style.css">
# </head>
# <body>
#     <div class="conent">
#         <div class="clientSvg">
#             <img src="https://imgcache.qq.com/qcloud/security/static/imgs/clientErr.svg" alt="">
#         </div>
#         <h1 class="err">很抱歉，您提交的请求存在异常，请向网站管理员确认并获取正确的访问方式</h1>
#         <p class="text1">本页面为<span class="text-color">腾讯T-Sec Web应用防火墙(WAF)</span>默认提示页面，如有疑问请联系网站管理员</p>
#     </div>
# </body>
# </html>
#
# []

# %%
all_info = []
for singUrl in url_list:
	print(singUrl)
	response = requests.get(singUrl, headers=headers).content.decode('utf-8')
	print(response)
	soup = BeautifulSoup(response, "lxml")
	# 名字
	name = soup.select('.celeInfo-right .name')[0].string
	name = name.replace(' ', '')

	#演员
	yyList = soup.select('.celebrity-group .celebrity-list .celebrity .info .name')
	yyStr = ''
	for i in yyList:
		yyStr +=i.string
	yyStr = yyStr.replace('\n', '')
	yyStr = yyStr.replace(' ', '')
	#导演
	dy = soup.select('.mod-content .celebrity-group .celebrity-list .info .name')[0].string

	#类型
	lxList = soup.select('.celeInfo-right .movie-brief-container .text-link')
	lxStr = ''
	for i in lxList:
		lxStr+=i.string
	lxStr = lxStr.replace(' ','')
	#上架时间
	sjsj = soup.select('.celeInfo-right .movie-brief-container .ellipsis')
	sjsjStr = sjsj[len(sjsj)-1].string
	sjsjStr = sjsjStr.replace(' ','')
	all_info.append([name,yyStr,dy,lxStr,sjsjStr])
	time.sleep(random.randint(20, 50))
print(all_info)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00b30c5de8e2> in <module>()
#       1 all_info = []
# ----> 2 for singUrl in url_list:
#       3         print(singUrl)
#       4         response = requests.get(singUrl, headers=headers).content.decode('utf-8')
#       5         print(response)
#
# NameError: name 'url_list' is not defined

# %%
#df = pd.DataFrame(all_info) #将获取到的所有数据生成表格
##设置下边表格的字段
#df.columns = ['名称', '演员', '导演', '类型','上架时间']

# %%
#df
# Out:
#         名称                                                 演员  \
# 0  哪吒之魔童降世  \n      饺子\n    \n      吕艳婷\n    \n      囧森瑟夫\...
# 1    我不是药神  \n      文牧野\n    \n      徐峥\n    \n      周一围\n...
# 2   肖申克的救赎  \n      弗兰克·德拉邦特\n    \n      蒂姆·罗宾斯\n    \n  ...
# 3    海上钢琴师  \n      朱塞佩·托纳多雷\n    \n      蒂姆·罗斯\n    \n   ...
# 4      绿皮书  \n      彼得·法雷里\n    \n      维果·莫腾森\n    \n    ...
# 5     小偷家族  \n      是枝裕和\n    \n      中川雅也\n    \n      安藤...
# 6     美丽人生  \n      罗伯托·贝尼尼\n    \n      罗伯托·贝尼尼\n    \n  ...
# 7     霸王别姬  \n      陈凯歌\n    \n      张国荣\n    \n      张丰毅\...
# 8  这个杀手不太冷  \n      吕克·贝松\n    \n      让·雷诺\n    \n      加...
# 9     触不可及  \n      奥利维埃·纳卡什\n    \n      埃里克·托莱达诺\n    \n...
#
#                      导演            类型              上架时间
# 0
#       饺子
#        动画  喜剧  奇幻   2019-07-26中国大陆上映
# 1
#       文牧野
#            剧情  喜剧   2018-07-05中国大陆上映
# 2
#       弗兰克·德拉邦特
#            剧情  犯罪     1994-09-13美国上映
# 3
#       朱塞佩·托纳多雷
#        剧情  爱情  音乐   2019-11-15中国大陆上映
# 4
#       彼得·法雷里
#        剧情  喜剧  传记   2019-03-01中国大陆上映
# 5
#       是枝裕和
#            剧情  犯罪   2018-08-03中国大陆上映
# 6
#       罗伯托·贝尼尼
#        战争  剧情  爱情   2020-01-03中国大陆上映
# 7
#       陈凯歌
#            剧情  爱情   1993-07-26中国大陆上映
# 8
#       吕克·贝松
#        剧情  动作  犯罪     1994-09-14法国上映
# 9
#       奥利维埃·纳卡什
#            剧情  喜剧     2011-11-02法国上映

# %%
#df.to_csv('测试.csv',encoding='utf_8_sig')

# %%
#df
