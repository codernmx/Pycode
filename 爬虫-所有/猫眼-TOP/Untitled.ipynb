# %%
import time
import xlwt
import requests
from bs4 import BeautifulSoup
import random
import pandas as pd

# %%
headers = {
    "Accept": 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    "Accept-Encoding": 'gzip, deflate, br',
    "Accept-Language": 'zh-CN,zh;q=0.9',
    "Cache-Control": 'max-age=0',
    "Connection": 'keep-alive',
    "Cookie": '__mta=48482713.1635159163254.1635159163254.1635159163254.1; __mta=48482713.1635159163254.1635159163254.1636109843763.2; _lxsdk_cuid=17cb714c0e0c8-033e82611b0dc3-3a67410c-144000-17cb714c0e1c8; uuid_n_v=v1; uuid=9674BC503BCD11ECB4F8514365831FE83313CBD44FCA442B9EBF16166F870D9A; _lx_utm=utm_source%3DBaidu%26utm_medium%3Dorganic; _lxsdk=9674BC503BCD11ECB4F8514365831FE83313CBD44FCA442B9EBF16166F870D9A; _csrf=c0897c2fe8b12a6664d889f6c2bb4883c27ead5915e9e87f1ccc14fa38c974ad; Hm_lvt_703e94591e87be68cc8da0da7cbd0be2=1635159163,1635261061,1635851473,1636109833; Hm_lpvt_703e94591e87be68cc8da0da7cbd0be2=1636109844; _lxsdk_s=17cefbed57e-1bc-1b3-505%7C%7C4',
    "Host": 'www.maoyan.com',
    # sec-ch-ua: "Chromium";v="92", " Not A;Brand";v="99", "Google Chrome";v="92",
    "sec-ch-ua-mobile": '?0',
    "Sec-Fetch-Dest": 'document',
    "Sec-Fetch-Mode": 'navigate',
    "Sec-Fetch-Site": 'none',
    "Sec-Fetch-User": '?1',
    "Upgrade-Insecure-Requests": '1',
    "User-Agent": 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36',
}

# %%
url_list = []  # 所有单个url
for iii in range(0, 1):
	url = 'https://maoyan.com/board/4?offset=' + str(iii) + '0'
	response = requests.get(url, headers=headers).content.decode('utf-8')
	print(response)
	soup = BeautifulSoup(response, "lxml")
	# url
	listUrl = soup.select('.image-link')
	for i in listUrl:
		url_list.append('https://maoyan.com' + str(i['href']))
# 	time.sleep(random.randint(20, 50))
print(url_list)
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 8]><html class="ie8"><![endif]-->
# <!--[if IE 9]><html class="ie9"><![endif]-->
# <!--[if gt IE 9]><!--><html><!--<![endif]-->
# <head>
#   <title>TOP100榜 - 猫眼电影 - 一网打尽好电影</title>
#
#   <link rel="dns-prefetch" href="//p0.meituan.net"  />
#   <link rel="dns-prefetch" href="//p1.meituan.net"  />
#   <link rel="dns-prefetch" href="//ms0.meituan.net" />
#   <link rel="dns-prefetch" href="//s0.meituan.net" />
#   <link rel="dns-prefetch" href="//ms1.meituan.net" />
#   <link rel="dns-prefetch" href="//analytics.meituan.com" />
#   <link rel="dns-prefetch" href="//report.meituan.com" />
#   <link rel="dns-prefetch" href="//frep.meituan.com" />
#
#
#   <meta charset="utf-8">
#   <meta name="keywords" content="猫眼电影,电影排行榜,热映口碑榜,最受期待榜,国内票房榜,北美票房榜,猫眼TOP100">
#   <meta name="description" content="猫眼电影热门榜单,包括热映口碑榜,最受期待榜,国内票房榜,北美票房榜,猫眼TOP100,多维度为用户进行选片决策">
#   <meta http-equiv="cleartype" content="yes" />
#   <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#   <meta name="renderer" content="webkit" />
#
#   <meta name="HandheldFriendly" content="true" />
#   <meta name="format-detection" content="email=no" />
#   <meta name="format-detection" content="telephone=no" />
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#
#
#   <script>"use strict";!function(){var i=0<arguments.length&&void 0!==arguments[0]?arguments[0]:"_Owl_",n=window;n[i]||(n[i]={isRunning:!1,isReady:!1,preTasks:[],dataSet:[],use:function(i,t){this.isReady&&n.Owl&&n.Owl[i](t),this.preTasks.push({api:i,data:[t]})},add:function(i){this.dataSet.push(i)},run:function(){var t=this;if(!this.isRunning){this.isRunning=!0;var i=n.onerror;n.onerror=function(){this.isReady||this.add({type:"jsError",data:arguments}),i&&i.apply(n,arguments)}.bind(this),(n.addEventListener||n.attachEvent)("error",function(i){t.isReady||t.add({type:"resError",data:[i]})},!0)}}},n[i].run())}();</script>
#   <script>
#   cid = "c_wx6zb55";
#   ci = 45;
# val = {"subnavId":4};    window.system = {};
#
#   window.openPlatform = '';
#   window.openPlatformSub = '';
#   window.$mtsiFlag = '0';
#   window.NODE_ENV = 'production';
#
#   </script>
#   <link rel="stylesheet" href="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/common.6b1d782c.css"/>
# <link rel="stylesheet" href="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/board-index.92a06072.css"/>
#   <script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/stat.88d57c80.js"></script>
#   <script>if(window.devicePixelRatio >= 2) { document.write('<link rel="stylesheet" href="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image-2x.8ba7074d.css"/>') }</script>
#   <style>
#     @font-face {
#       font-family: stonefont;
#       src: url('//vfile.meituan.net/colorstone/2e14533a44f94cf1cc8158f5b97c43683440.eot');
#       src: url('//vfile.meituan.net/colorstone/2e14533a44f94cf1cc8158f5b97c43683440.eot?#iefix') format('embedded-opentype'),
#            url('//vfile.meituan.net/colorstone/d958943057f323c46c2b15a441d364182288.woff') format('woff');
#     }
#
#     .stonefont {
#       font-family: stonefont;
#     }
#   </style>
#   <script>
#   var _hmt = _hmt || [];
#   (function() {
#   var hm = document.createElement("script");
#   hm.src = "https://hm.baidu.com/hm.js?703e94591e87be68cc8da0da7cbd0be2";
#   var s = document.getElementsByTagName("script")[0];
#   s.parentNode.insertBefore(hm, s);
#   })();
#   </script>
# </head>
# <body>
#
#
# <div class="header">
#   <div class="header-inner">
#           <a href="//www.maoyan.com" class="logo" data-act="icon-click">猫眼电影</a>
#         <div class="city-container" data-val="{currentcityid:45 }">
#             <div class="city-selected">
#                 <div class="city-name">
#                   重庆
#                   <span class="caret"></span>
#                 </div>
#             </div>
#             <div class="city-list" data-val="{ localcityid: 45 }">
#                 <div class="city-list-header">定位城市：<a class="js-geo-city" data-ci="45">重庆</a></div>
#             </div>
#         </div>
#
#
#         <div class="nav">
#             <ul class="navbar">
#                 <li><a href="/" data-act="home-click"  >首页</a></li>
#                 <li><a href="/films" data-act="movies-click" >电影</a></li>
#                 <li><a href="/cinemas" data-act="cinemas-click" >影院</a></li>
#                 <li><a href="http://www.gewara.com">演出</a></li>
#
#                 <li><a href="/board" data-act="board-click"  class="active" >榜单</a></li>
#                 <li><a href="/news" data-act="hotNews-click" >热点</a></li>
#                 <li><a href="/edimall"  >商城</a></li>
#             </ul>
#         </div>
#
#         <div class="user-info">
#             <div class="user-avatar J-login">
#               <img src="https://p0.meituan.net/movie/7dd82a16316ab32c8359debdb04396ef2897.png">
#               <span class="caret"></span>
#               <ul class="user-menu no-login-menu">
#                 <li><a href="javascript:void 0">登录</a></li>
#               </ul>
#             </div>
#         </div>
#
#         <form action="/query" target="_blank" class="search-form" data-actform="search-click">
#             <input name="kw" class="search" type="search" maxlength="32" placeholder="找影视剧、影人、影院" autocomplete="off">
#             <input class="submit" type="submit" value="">
#         </form>
#
#         <div class="app-download">
#           <a href="/app" target="_blank">
#             <span class="iphone-icon"></span>
#             <span class="apptext">APP下载</span>
#             <span class="caret"></span>
#             <div class="download-icon">
#                 <p class="down-title">扫码下载APP</p>
#                 <p class='down-content'>选座更优惠</p>
#             </div>
#           </a>
#         </div>
#
#   </div>
# </div>
# <div class="header-placeholder"></div>
#
# <div class="subnav">
#   <ul class="navbar">
#     <li>
#       <a data-act="subnav-click" data-val="{subnavClick:7}"
#           href="/board/7"
#       >热映口碑榜</a>
#     </li>
#     <li>
#       <a data-act="subnav-click" data-val="{subnavClick:6}"
#           href="/board/6"
#       >最受期待榜</a>
#     </li>
#     <li>
#       <a data-act="subnav-click" data-val="{subnavClick:1}"
#           href="/board/1"
#       >国内票房榜</a>
#     </li>
#     <li>
#       <a data-act="subnav-click" data-val="{subnavClick:2}"
#           href="/board/2"
#       >北美票房榜</a>
#     </li>
#     <li>
#       <a data-act="subnav-click" data-val="{subnavClick:4}"
#           data-state-val="{subnavId:4}"
#           class="active" href="javascript:void(0);"
#       >TOP100榜</a>
#     </li>
#   </ul>
# </div>
#
#
#     <div class="container" id="app" class="page-board/index" >
#
# <div class="content">
#     <div class="wrapper">
#         <div class="main">
#             <p class="update-time">2021-11-02<span class="has-fresh-text">已更新</span></p>
#             <p class="board-content">榜单规则：将猫眼电影库中的经典影片，按照评分和评分人数从高到低综合排序取前100名，每天上午10点更新。相关数据来源于“猫眼电影库”。</p>
#             <dl class="board-wrapper">
#                 <dd>
#                         <i class="board-index board-index-1">1</i>
#     <a href="/films/1200486" title="我不是药神" class="image-link" data-act="boarditem-click" data-val="{movieId:1200486}">
#       <img src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png" alt="" class="poster-default" />
#       <img data-src="https://p0.meituan.net/movie/414176cfa3fea8bed9b579e9f42766b9686649.jpg@160w_220h_1e_1c" alt="我不是药神" class="board-img" />
#     </a>
#     <div class="board-item-main">
#       <div class="board-item-content">
#               <div class="movie-item-info">
#         <p class="name"><a href="/films/1200486" title="我不是药神" data-act="boarditem-click" data-val="{movieId:1200486}">我不是药神</a></p>
#         <p class="star">
#                 主演：徐峥,周一围,王传君
#         </p>
# <p class="releasetime">上映时间：2018-07-05</p>    </div>
#     <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">6</i></p>
#     </div>
#
#       </div>
#     </div>
#
#                 </dd>
#                 <dd>
#                         <i class="board-index board-index-2">2</i>
#     <a href="/films/1297" title="肖申克的救赎" class="image-link" data-act="boarditem-click" data-val="{movieId:1297}">
#       <img src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png" alt="" class="poster-default" />
#       <img data-src="https://p0.meituan.net/movie/8112a8345d7f1d807d026282f2371008602126.jpg@160w_220h_1e_1c" alt="肖申克的救赎" class="board-img" />
#     </a>
#     <div class="board-item-main">
#       <div class="board-item-content">
#               <div class="movie-item-info">
#         <p class="name"><a href="/films/1297" title="肖申克的救赎" data-act="boarditem-click" data-val="{movieId:1297}">肖申克的救赎</a></p>
#         <p class="star">
#                 主演：蒂姆·罗宾斯,摩根·弗里曼,鲍勃·冈顿
#         </p>
# <p class="releasetime">上映时间：1994-09-10(加拿大)</p>    </div>
#     <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">5</i></p>
#     </div>
#
#       </div>
#     </div>
#
#                 </dd>
#                 <dd>
#                         <i class="board-index board-index-3">3</i>
#     <a href="/films/1206605" title="绿皮书" class="image-link" data-act="boarditem-click" data-val="{movieId:1206605}">
#       <img src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png" alt="" class="poster-default" />
#       <img data-src="https://p1.meituan.net/movie/c9b280de01549fcb71913edec05880585769972.jpg@160w_220h_1e_1c" alt="绿皮书" class="board-img" />
#     </a>
#     <div class="board-item-main">
#       <div class="board-item-content">
#               <div class="movie-item-info">
#         <p class="name"><a href="/films/1206605" title="绿皮书" data-act="boarditem-click" data-val="{movieId:1206605}">绿皮书</a></p>
#         <p class="star">
#                 主演：维果·莫腾森,马赫沙拉·阿里,琳达·卡德里尼
#         </p>
# <p class="releasetime">上映时间：2019-03-01</p>    </div>
#     <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">5</i></p>
#     </div>
#
#       </div>
#     </div>
#
#                 </dd>
#                 <dd>
#                         <i class="board-index board-index-4">4</i>
#     <a href="/films/1292" title="海上钢琴师" class="image-link" data-act="boarditem-click" data-val="{movieId:1292}">
#       <img src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png" alt="" class="poster-default" />
#       <img data-src="https://p0.meituan.net/movie/609e45bd40346eb8b927381be8fb27a61760914.jpg@160w_220h_1e_1c" alt="海上钢琴师" class="board-img" />
#     </a>
#     <div class="board-item-main">
#       <div class="board-item-content">
#               <div class="movie-item-info">
#         <p class="name"><a href="/films/1292" title="海上钢琴师" data-act="boarditem-click" data-val="{movieId:1292}">海上钢琴师</a></p>
#         <p class="star">
#                 主演：蒂姆·罗斯,比尔·努恩 ,克兰伦斯·威廉姆斯三世
#         </p>
# <p class="releasetime">上映时间：2019-11-15</p>    </div>
#     <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">3</i></p>
#     </div>
#
#       </div>
#     </div>
#
#                 </dd>
#                 <dd>
#                         <i class="board-index board-index-5">5</i>
#     <a href="/films/1211270" title="哪吒之魔童降世" class="image-link" data-act="boarditem-click" data-val="{movieId:1211270}">
#       <img src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png" alt="" class="poster-default" />
#       <img data-src="https://p0.meituan.net/movie/005955214d5b3e50c910d7a511b0cb571445301.jpg@160w_220h_1e_1c" alt="哪吒之魔童降世" class="board-img" />
#     </a>
#     <div class="board-item-main">
#       <div class="board-item-content">
#               <div class="movie-item-info">
#         <p class="name"><a href="/films/1211270" title="哪吒之魔童降世" data-act="boarditem-click" data-val="{movieId:1211270}">哪吒之魔童降世</a></p>
#         <p class="star">
#                 主演：吕艳婷,囧森瑟夫,瀚墨
#         </p>
# <p class="releasetime">上映时间：2019-07-26</p>    </div>
#     <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">6</i></p>
#     </div>
#
#       </div>
#     </div>
#
#                 </dd>
#                 <dd>
#                         <i class="board-index board-index-6">6</i>
#     <a href="/films/1203" title="霸王别姬" class="image-link" data-act="boarditem-click" data-val="{movieId:1203}">
#       <img src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png" alt="" class="poster-default" />
#       <img data-src="https://p0.meituan.net/movie/61fea77024f83b3700603f6af93bf690585789.jpg@160w_220h_1e_1c" alt="霸王别姬" class="board-img" />
#     </a>
#     <div class="board-item-main">
#       <div class="board-item-content">
#               <div class="movie-item-info">
#         <p class="name"><a href="/films/1203" title="霸王别姬" data-act="boarditem-click" data-val="{movieId:1203}">霸王别姬</a></p>
#         <p class="star">
#                 主演：张国荣,张丰毅,巩俐
#         </p>
# <p class="releasetime">上映时间：1993-07-26</p>    </div>
#     <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">4</i></p>
#     </div>
#
#       </div>
#     </div>
#
#                 </dd>
#                 <dd>
#                         <i class="board-index board-index-7">7</i>
#     <a href="/films/1216365" title="小偷家族" class="image-link" data-act="boarditem-click" data-val="{movieId:1216365}">
#       <img src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png" alt="" class="poster-default" />
#       <img data-src="https://p1.meituan.net/movie/ac8f0004928fbce5a038a007b7c73cec746794.jpg@160w_220h_1e_1c" alt="小偷家族" class="board-img" />
#     </a>
#     <div class="board-item-main">
#       <div class="board-item-content">
#               <div class="movie-item-info">
#         <p class="name"><a href="/films/1216365" title="小偷家族" data-act="boarditem-click" data-val="{movieId:1216365}">小偷家族</a></p>
#         <p class="star">
#                 主演：中川雅也,安藤樱,松冈茉优
#         </p>
# <p class="releasetime">上映时间：2018-08-03</p>    </div>
#     <div class="movie-item-number score-num">
# <p class="score"><i class="integer">8.</i><i class="fraction">1</i></p>
#     </div>
#
#       </div>
#     </div>
#
#                 </dd>
#                 <dd>
#                         <i class="board-index board-index-8">8</i>
#     <a href="/films/1303" title="美丽人生" class="image-link" data-act="boarditem-click" data-val="{movieId:1303}">
#       <img src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png" alt="" class="poster-default" />
#       <img data-src="https://p1.meituan.net/movie/580d81a2c78bf204f45323ddb4244b6c6821175.jpg@160w_220h_1e_1c" alt="美丽人生" class="board-img" />
#     </a>
#     <div class="board-item-main">
#       <div class="board-item-content">
#               <div class="movie-item-info">
#         <p class="name"><a href="/films/1303" title="美丽人生" data-act="boarditem-click" data-val="{movieId:1303}">美丽人生</a></p>
#         <p class="star">
#                 主演：罗伯托·贝尼尼,朱斯蒂诺·杜拉诺,赛尔乔·比尼·布斯特里克
#         </p>
# <p class="releasetime">上映时间：2020-01-03</p>    </div>
#     <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">3</i></p>
#     </div>
#
#       </div>
#     </div>
#
#                 </dd>
#                 <dd>
#                         <i class="board-index board-index-9">9</i>
#     <a href="/films/4055" title="这个杀手不太冷" class="image-link" data-act="boarditem-click" data-val="{movieId:4055}">
#       <img src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png" alt="" class="poster-default" />
#       <img data-src="https://p1.meituan.net/movie/6bea9af4524dfbd0b668eaa7e187c3df767253.jpg@160w_220h_1e_1c" alt="这个杀手不太冷" class="board-img" />
#     </a>
#     <div class="board-item-main">
#       <div class="board-item-content">
#               <div class="movie-item-info">
#         <p class="name"><a href="/films/4055" title="这个杀手不太冷" data-act="boarditem-click" data-val="{movieId:4055}">这个杀手不太冷</a></p>
#         <p class="star">
#                 主演：让·雷诺,加里·奥德曼,娜塔莉·波特曼
#         </p>
# <p class="releasetime">上映时间：1994-09-14(法国)</p>    </div>
#     <div class="movie-item-number score-num">
# <p class="score"><i class="integer">9.</i><i class="fraction">4</i></p>
#     </div>
#
#       </div>
#     </div>
#
#                 </dd>
#                 <dd>
#                         <i class="board-index board-index-10">10</i>
#     <a href="/films/46818" title="怦然心动" class="image-link" data-act="boarditem-click" data-val="{movieId:46818}">
#       <img src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png" alt="" class="poster-default" />
#       <img data-src="https://p0.meituan.net/movie/15f1ac49b6d1ff7b71207672993ed6901536456.jpg@160w_220h_1e_1c" alt="怦然心动" class="board-img" />
#     </a>
#     <div class="board-item-main">
#       <div class="board-item-content">
#               <div class="movie-item-info">
#         <p class="name"><a href="/films/46818" title="怦然心动" data-act="boarditem-click" data-val="{movieId:46818}">怦然心动</a></p>
#         <p class="star">
#                 主演：玛德琳·卡罗尔,卡兰·麦克奥利菲,艾丹•奎因
#         </p>
# <p class="releasetime">上映时间：2010-07-26(美国)</p>    </div>
#     <div class="movie-item-number score-num">
# <p class="score"><i class="integer">8.</i><i class="fraction">9</i></p>
#     </div>
#
#       </div>
#     </div>
#
#                 </dd>
#             </dl>
#
#         </div>
#             <div class="pager-main">
#
#
#   <ul class="list-pager">
#
#
#
#
#       <li class="active">
#     <a class="page_1"
#       href="javascript:void(0);" style="cursor: default"
#   >1</a>
#
# </li>
#   <li >
#     <a class="page_2"
#       href="?offset=10"
#   >2</a>
#
# </li>
#   <li >
#     <a class="page_3"
#       href="?offset=20"
#   >3</a>
#
# </li>
#   <li >
#     <a class="page_4"
#       href="?offset=30"
#   >4</a>
#
# </li>
#   <li >
#     <a class="page_5"
#       href="?offset=40"
#   >5</a>
#
# </li>
#
#     <li class="sep">...</li>
#       <li >
#     <a class="page_10"
#       href="?offset=90"
#   >10</a>
#
# </li>
#
#
#
# <li>  <a class="page_2"
#       href="?offset=10"
#   >下一页</a>
# </li>
# </ul>
#
#
#             </div>
#     </div>
# </div>
#
#     </div>
#
# <div class="footer">
#   <p class="friendly-links">
#     关于猫眼 :
#     <a href="http://ir.maoyan.com/s/index.php#pageScroll0" target="_blank">关于我们</a>
#     <span></span>
#     <a href="http://ir.maoyan.com/s/index.php#pageScroll1" target="_blank">管理团队</a>
#     <span></span>
#     <a href="http://ir.maoyan.com/s/index.php#pageScroll2" target="_blank">投资者关系</a>
#     &nbsp;&nbsp;&nbsp;&nbsp;
#     友情链接 :
#     <a href="http://www.meituan.com" data-query="utm_source=wwwmaoyan" target="_blank">美团网</a>
#     <span></span>
#     <a href="http://www.gewara.com" data-query="utm_source=wwwmaoyan">格瓦拉</a>
#     <span></span>
#     <a href="http://i.meituan.com/client" data-query="utm_source=wwwmaoyan" target="_blank">美团下载</a>
#     <span></span>
#     <a href="https://www.huanxi.com" data-query="utm_source=maoyan_pc" target="_blank">欢喜首映</a>
#   </p>
#   <p class="friendly-links">
#     商务合作邮箱：v@maoyan.com
#     客服电话：10105335
#     违法和不良信息/涉未成年人有害信息举报电话：4006018900
#   </p>
#   <p class="friendly-links">
#     用户举报/涉未成年人有害信息举报邮箱：tousujubao@meituan.com
#     舞弊线索举报邮箱：wubijubao@maoyan.com
#   </p>
#   <p class="friendly-links  credentials">
#     <a href="/about/licence/1" target="_blank">中华人民共和国增值电信业务经营许可证 京B2-20190350</a>
#     <span></span>
#     <a href="/about/licence/4" target="_blank">营业性演出许可证 京演（机构）（2019）4094号</a>
#   </p>
#   <p class="friendly-links  credentials">
#     <a href="/about/licence/3" target="_blank">广播电视节目制作经营许可证 （京）字第08478号</a>
#     <span></span>
#     <a href="/about/licence/2" target="_blank">网络文化经营许可证 京网文（2019）3837-369号 </a>
#   </p>
#   <p class="friendly-links  credentials">
#     <a href="/rules/agreement" target="_blank">猫眼用户服务协议 </a>
#     <span></span>
#     <a href="/rules/rule" target="_blank">猫眼平台交易规则总则 </a>
#     <span></span>
#     <a href="/rules/privacy" target="_blank">隐私政策 </a>
#   </p>
#   <p class="friendly-links  credentials">
#     <a href="http://www.beian.gov.cn/portal/registerSystemInfo?recordcode=11010102003232" target="_blank">京公网安备
#       11010102003232号</a>
#     <span></span>
#     <a href="http://beian.miit.gov.cn/" target="_blank">京ICP备16022489号-1</a>
#   </p>
#   <p>北京猫眼文化传媒有限公司</p>
#   <p>
#     &copy;<span class="my-footer-year">2016</span>
#     猫眼电影 www.maoyan.com</p>
#   <div class="certificate">
#     <a href="http://sq.ccm.gov.cn:80/ccnt/sczr/service/business/emark/toDetail/350CF8BCA8416C4FE0530140A8C0957E"
#       target="_blank">
#       <img src="https://p0.meituan.net/moviemachine/e54374ccf134d1f7b2c5b075a74fca525326.png" />
#     </a>
#     <a href="/about/licence/5" target="_blank">
#       <img src="https://p1.meituan.net/moviemachine/805f605d5cf1b1a02a4e3a5e29df003b8376.png" />
#     </a>
#     <a href="https://www.12377.cn" target="_blank">
#       <img src="https://p0.meituan.net/scarlett/3cd2a9b7dc179531d20d27a5fd686e783787.png" />
#     </a>
#   </div>
# </div>
#
#     <script crossorigin="anonymous" src="//www.dpfile.com/app/owl/static/owl_1.7.11.js"></script>
#     <script>
#       Owl.start({
#         project: 'com.sankuai.movie.fe.mywww',
#         pageUrl: location.href.split('?')[0].replace(/\/\d+/g, '/:id'),
#         devMode: false
#       })
#     </script>
#     <!--[if IE 8]><script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/es5-shim.bbad933f.js"></script><![endif]-->
#     <!--[if IE 8]><script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/es5-sham.d6ea26f4.js"></script><![endif]-->
#     <script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/common.850e1cac.js"></script>
# <script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/board-index.7a3a81e3.js"></script>
# </body>
# </html>
#
# ['https://maoyan.com/films/1200486', 'https://maoyan.com/films/1297', 'https://maoyan.com/films/1206605', 'https://maoyan.com/films/1292', 'https://maoyan.com/films/1211270', 'https://maoyan.com/films/1203', 'https://maoyan.com/films/1216365', 'https://maoyan.com/films/1303', 'https://maoyan.com/films/4055', 'https://maoyan.com/films/46818']

# %%
all_info = []
for singUrl in url_list:
	print(singUrl)
	response = requests.get(singUrl, headers=headers).content.decode('utf-8')
	print(response)
	soup = BeautifulSoup(response, "lxml")
	# 名字
	name = soup.select('.celeInfo-right .name')[0].string
	name = name.replace(' ', '')

	#演员
	yyList = soup.select('.celebrity-group .celebrity-list .celebrity .info .name')
	yyStr = ''
	for i in yyList:
		yyStr +=i.string
	yyStr = yyStr.replace('\n', '')
	yyStr = yyStr.replace(' ', '')
	#导演
	dy = soup.select('.mod-content .celebrity-group .celebrity-list .info .name')[0].string

	#类型
	lxList = soup.select('.celeInfo-right .movie-brief-container .text-link')
	lxStr = ''
	for i in lxList:
		lxStr+=i.string
	lxStr = lxStr.replace(' ','')
	#上架时间
	sjsj = soup.select('.celeInfo-right .movie-brief-container .ellipsis')
	sjsjStr = sjsj[len(sjsj)-1].string
	sjsjStr = sjsjStr.replace(' ','')
	all_info.append([name,yyStr,dy,lxStr,sjsjStr])
	time.sleep(random.randint(20, 50))
print(all_info)
# Out:
# https://maoyan.com/films/1200486
# <!DOCTYPE html>
#
# <!--[if IE 8]><html class="ie8"><![endif]-->
# <!--[if IE 9]><html class="ie9"><![endif]-->
# <!--[if gt IE 9]><!--><html><!--<![endif]-->
# <head>
#   <title>我不是药神_购票_剧情介绍_演职人员_图集_猫眼电影</title>
#
#   <link rel="dns-prefetch" href="//p0.meituan.net"  />
#   <link rel="dns-prefetch" href="//p1.meituan.net"  />
#   <link rel="dns-prefetch" href="//ms0.meituan.net" />
#   <link rel="dns-prefetch" href="//s0.meituan.net" />
#   <link rel="dns-prefetch" href="//ms1.meituan.net" />
#   <link rel="dns-prefetch" href="//analytics.meituan.com" />
#   <link rel="dns-prefetch" href="//report.meituan.com" />
#   <link rel="dns-prefetch" href="//frep.meituan.com" />
#   <link rel="alternate" media="only screen and (max-width: 640px)"  href="https://m.maoyan.com/asgard/movie/1200486" />
#   <link rel="canonical" href="https://www.maoyan.com/films/1200486" />
#
#
#   <meta charset="utf-8">
#   <meta name="keywords" content="我不是药神,徐峥,周一围,王传君,文牧野,选座购票,剧情介绍">
#   <meta name="description" content="印度神油店老板程勇日子过得窝囊，店里没生意，老父病危，手术费筹不齐。前妻跟有钱人怀上了孩子，还要把他儿子的抚养权给拿走。一日，店里来了一个白血病患者，求">
#   <meta http-equiv="cleartype" content="yes" />
#   <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#   <meta name="renderer" content="webkit" />
#
#   <meta name="HandheldFriendly" content="true" />
#   <meta name="format-detection" content="email=no" />
#   <meta name="format-detection" content="telephone=no" />
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#
#
#   <script>"use strict";!function(){var i=0<arguments.length&&void 0!==arguments[0]?arguments[0]:"_Owl_",n=window;n[i]||(n[i]={isRunning:!1,isReady:!1,preTasks:[],dataSet:[],use:function(i,t){this.isReady&&n.Owl&&n.Owl[i](t),this.preTasks.push({api:i,data:[t]})},add:function(i){this.dataSet.push(i)},run:function(){var t=this;if(!this.isRunning){this.isRunning=!0;var i=n.onerror;n.onerror=function(){this.isReady||this.add({type:"jsError",data:arguments}),i&&i.apply(n,arguments)}.bind(this),(n.addEventListener||n.attachEvent)("error",function(i){t.isReady||t.add({type:"resError",data:[i]})},!0)}}},n[i].run())}();</script>
#   <script>
#   cid = "c_47wrcgg";
#   ci = 45;
# val = {"id":1200486};    window.system = {"movieId":"1200486","imgs":["http://p0.meituan.net/movie/574c998b534c4354e46e8c0cf89ca76037249.jpg@2500w_2500h_1l_0e","http://p1.meituan.net/movie/27e79cac1d425693cde2b7b0a41c4dee65620.jpg@2500w_2500h_1l_0e","http://p0.meituan.net/movie/0ef7879adf5d59b4cda6de7b6d71cea958180.jpg@2500w_2500h_1l_0e","http://p0.meituan.net/movie/90d459cd24b00175abd67e0305e929ef31568.jpg@2500w_2500h_1l_0e","http://p1.meituan.net/movie/d02366183b8492a6bba932449fd4564077080.jpg@2500w_2500h_1l_0e","http://p0.meituan.net/movie/b04db0fa5a44aaef82cea1bcea24a2ea72181.jpg@2500w_2500h_1l_0e","http://p1.meituan.net/movie/3a170c014833998d2b70be787a342d9559620.jpg@2500w_2500h_1l_0e","http://p1.meituan.net/movie/5ec75b2fcacf65f1854123399cd9fcef36306.jpg@2500w_2500h_1l_0e","http://p1.meituan.net/movie/1bf0bc0973effaf9367db8afea2c66e054260.jpg@2500w_2500h_1l_0e","http://p0.meituan.net/movie/fdfc04fa6e6000a83a3ccfe7542dd2f047886.jpg@2500w_2500h_1l_0e","http://p0.meituan.net/movie/7aecd8039008e7e75a1e91d883fc701b85639.jpg@2500w_2500h_1l_0e","http://p1.meituan.net/movie/146b4ca6e94b8a5f9b934e6ea2fdfad122852.jpg@2500w_2500h_1l_0e","http://p0.meituan.net/movie/5ecb1d8612585fa752bede8b0072a80956195.jpg@2500w_2500h_1l_0e","http://p1.meituan.net/movie/788171df28388f8cc30f558772bacbe3101510.jpg@2500w_2500h_1l_0e","http://p0.meituan.net/movie/0e515ac2fe5dc0fb402fd88577bc566193251.jpg@2500w_2500h_1l_0e","http://p1.meituan.net/movie/f67e1312c55f91471bea30872071f95c140503.jpg@2500w_2500h_1l_0e","http://p1.meituan.net/movie/078033653fe88e2153b319fbbdb9344552122.jpg@2500w_2500h_1l_0e","http://p0.meituan.net/movie/910abf15a84184e9966ac63be868d64170270.jpg@2500w_2500h_1l_0e","http://p1.meituan.net/movie/b62cee24637eab6e33d035d83ca3644488851.jpg@2500w_2500h_1l_0e","http://p1.meituan.net/movie/cb464bf06d0c0316af24afb7b9d20c6547010.jpg@2500w_2500h_1l_0e","http://p1.meituan.net/movie/dac6f7477d45fb0e0fe58defa3db57f588649.jpg@2500w_2500h_1l_0e","http://p0.meituan.net/movie/e0255df13123144cb5814a1b58b22d6665275.jpg@2500w_2500h_1l_0e","http://p1.meituan.net/movie/95330b912681a4e5bd269c333060dcf772015.jpg@2500w_2500h_1l_0e","http://p0.meituan.net/movie/29de434e8ec3053e279b5794f140ab2788522.jpg@2500w_2500h_1l_0e","http://p1.meituan.net/movie/f4d49e2e3dbbe26640ed07ac7d0a209752505.jpg@2500w_2500h_1l_0e","http://p0.meituan.net/movie/3e7af4f4338cbaf6991480d4d9c7e81254082.jpg@2500w_2500h_1l_0e","http://p1.meituan.net/movie/bd4723215f08f6285c88a004f1bc9a2f80122.jpg@2500w_2500h_1l_0e","http://p0.meituan.net/movie/e4c353ae42cf66d138e77e71b79f54d773366.jpg@2500w_2500h_1l_0e","http://p0.meituan.net/movie/3c77f4de2de6ca8f720a097961156a4276313.jpg@2500w_2500h_1l_0e","http://p1.meituan.net/movie/8699083631fc50f425f386bb1f1187bd70543.jpg@2500w_2500h_1l_0e","http://p1.meituan.net/movie/fa8454a2a7f567b92350b7d023d492f771385.jpg@2500w_2500h_1l_0e","http://p0.meituan.net/movie/761f7f70588e2d31f01941ed2b122c0080067.jpg@2500w_2500h_1l_0e","http://p1.meituan.net/movie/ed050b2827ff8e7c7dc58e7c48688e0e42194.jpg@2500w_2500h_1l_0e","http://p1.meituan.net/movie/3065271341357040f5f5dd988550951e586199.jpg","http://p1.meituan.net/movie/6b2b3fd6260ac37e5ad44d00ea474ea3651419.jpg","http://p1.meituan.net/movie/4633dd44c51ff15fc7e939679d7cdb67561602.jpg","http://p0.meituan.net/movie/df2d30b1a3bd58fb1d38b978662ae844648169.jpg","http://p1.meituan.net/movie/c845f6b04aa49059951fd55e6b0eddac454036.jpg","http://p1.meituan.net/movie/f70135b616b6d263a3b38bf12c68d2d8561858.jpg","http://p1.meituan.net/movie/0397be60a66479447266b628c314b70f628512.jpg","http://p1.meituan.net/movie/5a629a81b2d21eb5b5709fee25c3fafc677226.jpg","http://p1.meituan.net/movie/19378630bcf14ad9326d2938b58aa8ad768953.jpg","http://p1.meituan.net/movie/9d961088a3b45f0ca53f9a97aa84d0c7618377.jpg","http://p1.meituan.net/movie/eef2104abb631bf88c6ce0c33ff8cca4644061.jpg","http://p0.meituan.net/movie/8b47bffc0212f854f352558a40a8405a552753.jpg","http://p0.meituan.net/movie/8fbae98a873beb591bbfd6e9d01913f0633588.jpg","http://p ...
#
#   window.openPlatform = '';
#   window.openPlatformSub = '';
#   window.$mtsiFlag = '0';
#   window.NODE_ENV = 'production';
#
#   </script>
#   <link rel="stylesheet" href="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/common.6b1d782c.css"/>
# <link rel="stylesheet" href="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/movie-detail.82e42188.css"/>
#   <script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/stat.88d57c80.js"></script>
#   <script>if(window.devicePixelRatio >= 2) { document.write('<link rel="stylesheet" href="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image-2x.8ba7074d.css"/>') }</script>
# <script>
#   window.mta && mta('tag', 'page', '/films/-id-')
# </script>
#   <style>
#     @font-face {
#       font-family: stonefont;
#       src: url('//vfile.meituan.net/colorstone/024dda1a5070c207191b60a33c6d764a3440.eot');
#       src: url('//vfile.meituan.net/colorstone/024dda1a5070c207191b60a33c6d764a3440.eot?#iefix') format('embedded-opentype'),
#            url('//vfile.meituan.net/colorstone/80fc71ce25e97590382fe836682deaf32276.woff') format('woff');
#     }
#
#     .stonefont {
#       font-family: stonefont;
#     }
#   </style>
#   <script>
#   var _hmt = _hmt || [];
#   (function() {
#   var hm = document.createElement("script");
#   hm.src = "https://hm.baidu.com/hm.js?703e94591e87be68cc8da0da7cbd0be2";
#   var s = document.getElementsByTagName("script")[0];
#   s.parentNode.insertBefore(hm, s);
#   })();
#   </script>
# </head>
# <body>
#
#
# <div class="header">
#   <div class="header-inner">
#           <a href="//www.maoyan.com" class="logo" data-act="icon-click">猫眼电影</a>
#         <div class="city-container" data-val="{currentcityid:45 }">
#             <div class="city-selected">
#                 <div class="city-name">
#                   重庆
#                   <span class="caret"></span>
#                 </div>
#             </div>
#             <div class="city-list" data-val="{ localcityid: 45 }">
#                 <div class="city-list-header">定位城市：<a class="js-geo-city" data-ci="45">重庆</a></div>
#             </div>
#         </div>
#
#
#         <div class="nav">
#             <ul class="navbar">
#                 <li><a href="/" data-act="home-click"  >首页</a></li>
#                 <li><a href="/films" data-act="movies-click" >电影</a></li>
#                 <li><a href="/cinemas" data-act="cinemas-click" >影院</a></li>
#                 <li><a href="http://www.gewara.com">演出</a></li>
#
#                 <li><a href="/board" data-act="board-click" >榜单</a></li>
#                 <li><a href="/news" data-act="hotNews-click" >热点</a></li>
#                 <li><a href="/edimall"  >商城</a></li>
#             </ul>
#         </div>
#
#         <div class="user-info">
#             <div class="user-avatar J-login">
#               <img src="https://p0.meituan.net/movie/7dd82a16316ab32c8359debdb04396ef2897.png">
#               <span class="caret"></span>
#               <ul class="user-menu no-login-menu">
#                 <li><a href="javascript:void 0">登录</a></li>
#               </ul>
#             </div>
#         </div>
#
#         <form action="/query" target="_blank" class="search-form" data-actform="search-click">
#             <input name="kw" class="search" type="search" maxlength="32" placeholder="找影视剧、影人、影院" autocomplete="off">
#             <input class="submit" type="submit" value="">
#         </form>
#
#         <div class="app-download">
#           <a href="/app" target="_blank">
#             <span class="iphone-icon"></span>
#             <span class="apptext">APP下载</span>
#             <span class="caret"></span>
#             <div class="download-icon">
#                 <p class="down-title">扫码下载APP</p>
#                 <p class='down-content'>选座更优惠</p>
#             </div>
#           </a>
#         </div>
#
#   </div>
# </div>
# <div class="header-placeholder"></div>
#
#   <div class="banner">
#     <div class="wrapper clearfix">
#       <div class="celeInfo-left">
#         <div class="avatar-shadow">
#           <img class="avatar" src="https://p0.meituan.net/movie/414176cfa3fea8bed9b579e9f42766b9686649.jpg@464w_644h_1e_1c" alt="我不是药神海报封面">
#             <div class="movie-ver"><i class="imax2d"></i></div>
#         </div>
#       </div>
#       <div class="celeInfo-right clearfix">
#             <div class="movie-brief-container" >
#       <h1 class="name">我不是药神</h1>
#       <div class="ename ellipsis">Dying To Survive</div>
#       <ul>
#         <li class="ellipsis">
#             <a class="text-link" href="/films?catId=1"  target="_blank"> 剧情 </a>
#             <a class="text-link" href="/films?catId=2"  target="_blank"> 喜剧 </a>
#         </li>
#         <li class="ellipsis">
#         中国大陆
#           / 117分钟
#         </li>
#         <li class="ellipsis">2018-07-05中国大陆上映</li>
#       </ul>
#     </div>
#     <div class="action-buyBtn">
#       <div class="action clearfix" data-val="{movieid:1200486}">
#         <a class="wish " data-wish="false" data-score="" data-bid="b_gbxqtw6x">
#           <div>
#             <i class="icon wish-icon"></i>
#               <span class="wish-msg" data-act="wish-click">想看</span>
#           </div>
#         </a>
#         <a class="score-btn " data-bid="b_rxxpcgwd">
#           <div>
#             <i class="icon score-btn-icon"></i>
#             <span class="score-btn-msg" data-act="comment-open-click">
#                 评分
#             </span>
#           </div>
#         </a>
#       </div>
#     </div>
#
#     <div class="movie-stats-container">
#
#         <div class="movie-index">
#           <p class="movie-index-title">猫眼口碑</p>
#           <div class="movie-index-content score normal-score">
#               <span class="index-left info-num ">
#                 <span class="stonefont">&#xe918;.&#xe5a9;</span>
#               </span>
#               <div class="index-right">
#                 <div class='star-wrapper'>
#                   <div class="star-on" style="width:96%;"></div>
#                 </div>
#                  <span class='score-num'><span class="stonefont">&#xf2a9;&#xf842;&#xe1d7;.&#xe918;万</span>人评分</span>
#               </div>
#           </div>
#         </div>
#
#
#
#         <div class="movie-index">
#           <p class="movie-index-title">累计票房</p>
#           <div class="movie-index-content box">
#               <span class="stonefont">&#xea12;&#xe1d7;.&#xe72a;&#xe72a;</span><span class="unit">亿</span>
#           </div>
#         </div>
#     </div>
#
#       </div>
#     </div>
# </div>
#
#
#     <div class="container" id="app" class="page-movie/detail" >
# <div class="main-content-container clearfix">
#   <div class="main-content">
#     <div class="tab-container tab-movie-info">
#       <div class="crumbs-nav-container">
#           <a href='/' >猫眼电影</a> &gt; <a href='/films' >电影</a> &gt; <span>我不是药神</span>
#       </div>
#       <div class="tab-title-container clearfix">
#         <div class="tab-title active" data-act="tab-desc-click">介绍</div>
#         <div class="tab-title " data-act="tab-celebrity-click">演职人员</div>
#         <div class="tab-title " data-act="tab-award-click">奖项</div>
#         <div class="tab-title " data-act="tab-img-click">图集</div>
#       </div>
#       <div class="tab-content-container">
#         <div class="tab-desc tab-content active" data-val="{tabtype:'desc'}">
#
#   <div class="module">
#     <div class="mod-title">
#       <h2>剧情简介</h2>
#     </div>
#     <div class="mod-content">
#                     <span class="dra">印度神油店老板程勇日子过得窝囊，店里没生意，老父病危，手术费筹不齐。前妻跟有钱人怀上了孩子，还要把他儿子的抚养权给拿走。一日，店里来了一个白血病患者，求他从印度带回一批仿制的特效药，好让买不起天价正版药的患者保住一线生机。百般不愿却走投无路的程勇，意外因此一夕翻身，平价特效药救人无数，让他被病患封为“药神”，但随着利益而来的，是一场让他的生活以及贫穷病患性命都陷入危机的多方拉锯战  。</span>
#
#     </div>
#   </div>
#
#
#   <div class="module">
#     <div class="mod-title">
#       <h2>演职人员</h2>
#         <a class="more" href=#celebrity data-act="all-actor-click">全部</a>
#     </div>
#     <div class="mod-content">
#                       <div class="celebrity-container clearfix" >
#
#                     <div class="celebrity-group">
#   <div class="celebrity-type">
#     导演
#   </div>
#   <ul class="celebrity-list clearfix">
#       <li class="celebrity " data-act="celebrity-click" data-val="{celebrityid:476574}">
#   <a href="/films/celebrity/476574" target="_blank" class="portrait">
#     <img class="default-img" data-src="https://p0.meituan.net/moviemachine/ca83458f40b73622d8bb9a20721fc9e0170261.jpg@128w_170h_1e_1c" alt="我不是药神 文牧野" />
#   </a>
#   <div class="info">
#     <a href="/films/celebrity/476574" target="_blank" class="name">
#       文牧野
#     </a>
#   </div>
# </li>
#
#   </ul>
# </div>
#
#
#                     <div class="celebrity-group">
#   <div class="celebrity-type">
#     演员
#   </div>
#   <ul class="celebrity-list clearfix">
#       <li class="celebrity actor" data-act="celebrity-click" data-val="{celebrityid:28608}">
#   <a href="/films/celebrity/28608" target="_blank" class="portrait">
#     <img class="default-img" data-src="https://p1.meituan.net/movie/8a5793c16dce09b98c51164cf8419b97134679.jpg@128w_170h_1e_1c" alt="我不是药神 徐峥" />
#   </a>
#   <div class="info">
#     <a href="/films/celebrity/28608" target="_blank" class="name">
#       徐峥
#     </a>
#       <br /><span class="role">饰：程勇</span>
#   </div>
# </li>
#
#       <li class="celebrity actor" data-act="celebrity-click" data-val="{celebrityid:29462}">
#   <a href="/films/celebrity/29462" target="_blank" class="portrait">
#     <img class="default-img" data-src="https://p0.meituan.net/moviemachine/533aa68002bee5bbbbedfad7ba7c56b356761.jpg@128w_170h_1e_1c" alt="我不是药神 周一围" />
#   </a>
#   <div class="info">
#     <a href="/films/celebrity/29462" target="_blank" class="name">
#       周一围
#     </a>
#       <br /><span class="role">饰：曹斌</span>
#   </div>
# </li>
#
#       <li class="celebrity actor" data-act="celebrity-click" data-val="{celebrityid:1795}">
#   <a href="/films/celebrity/1795" target="_blank" class="portrait">
#     <img class="default-img" data-src="https://p0.meituan.net/movie/b782d497577baffb5ed14de52841dcb164365.jpg@128w_170h_1e_1c" alt="我不是药神 王传君" />
#   </a>
#   <div class="info">
#     <a href="/films/celebrity/1795" target="_blank" class="name">
#       王传君
#     </a>
#       <br /><span class="role">饰：吕受益</span>
#   </div>
# </li>
#
#       <li class="celebrity actor" data-act="celebrity-click" data-val="{celebrityid:2730}">
#   <a href="/films/celebrity/2730" target="_blank" class="portrait">
#     <img class="default-img" data-src="https://p0.meituan.net/moviemachine/5173e16561b0c0e1949588a080987b7024599.jpg@128w_170h_1e_1c" alt="我不是药神 谭卓" />
#   </a>
#   <div class="info">
#     <a href="/films/celebrity/2730" target="_blank" class="name">
#       谭卓
#     </a>
#       <br /><span class="role">饰：刘思慧</span>
#   </div>
# </li>
#
#   </ul>
# </div>
#
#                 </div>
#
#     </div>
#   </div>
#
#   <div class="module">
#     <div class="mod-title">
#       <h2>奖项</h2>
#         <a class="more" href=#award data-act="all-award-click">全部</a>
#     </div>
#     <div class="mod-content">
#                     <ul class="award-list">
#   <li class="award-item ">
#     <div>
#       <div class="portrait">
#         <img src="https://p1.meituan.net/movie/93c7e76ea0613b230023c7f0348e77327514.jpg@50w_50h_1e_1c" alt="">
#       </div>
#       第38届香港金像奖
#     </div>
#     <div class="content">
#         <div>获奖：最佳两岸华语电影</div>
#     </div>
#   </li>
#   <li class="award-item last">
#     <div>
#       <div class="portrait">
#         <img src="https://p1.meituan.net/movie/b4fee6afd042d546bd8ec85605a64d385478.jpg@50w_50h_1e_1c" alt="">
#       </div>
#       第55届台湾电影金马奖
#     </div>
#     <div class="content">
#         <div>获奖：最佳男主角 / 最佳新导演 / 最佳原著剧本</div>
#         <div>提名：最佳剧情片 / 最佳男配角 / 最佳造型设计 / 最佳剪辑</div>
#     </div>
#   </li>
# </ul>
#
#
#     </div>
#   </div>
#
#   <div class="module">
#     <div class="mod-title">
#       <h2>图集</h2>
#         <a class="more" href=#img data-act="all-photo-click">全部</a>
#     </div>
#     <div class="mod-content">
#                     <div class="album clearfix" data-act="movie-img-click">
#                     <div class="img1"><img class="default-img" data-src="https://p0.meituan.net/movie/574c998b534c4354e46e8c0cf89ca76037249.jpg@465w_258h_1e_1c" alt="我不是药神剧照图集" /></div>
#                     <div class="img2"><img class="default-img" data-src="https://p1.meituan.net/movie/27e79cac1d425693cde2b7b0a41c4dee65620.jpg@126w_126h_1e_1c" alt="我不是药神剧照图集" /></div>
#                     <div class="img3"><img class="default-img" data-src="https://p0.meituan.net/movie/0ef7879adf5d59b4cda6de7b6d71cea958180.jpg@126w_126h_1e_1c" alt="我不是药神剧照图集" /></div>
#                     <div class="img4"><img class="default-img" data-src="https://p0.meituan.net/movie/90d459cd24b00175abd67e0305e929ef31568.jpg@126w_126h_1e_1c" alt="我不是药神剧照图集" /></div>
#                     <div class="img5"><img class="default-img" data-src="https://p1.meituan.net/movie/d02366183b8492a6bba932449fd4564077080.jpg@126w_126h_1e_1c" alt="我不是药神剧照图集" /></div>
#               </div>
#
#     </div>
#   </div>
#
#
#   <div class="module">
#     <div class="mod-title">
#       <h2>热门短评</h2>
#     </div>
#     <div class="mod-content">
#                   <div class="comment-list-container" data-hot=10>
#
# <ul>
#     <li class="comment-container " data-val="{commentid:1026981572}">
#       <div class="portrait-container">
#         <div class="portrait">
#           <img src="https://img.meituan.net/avatar/b07fe330b3b11713ff096390d60d3a9b7039.jpg@100w_100h_1e_1c" alt="">
#         </div>
#         <i class="level-2-icon"></i>
#       </div>
#       <div class="main">
#         <div class="main-header clearfix">
#           <div class="user">
#             <span class="name">乐Forwards</span>
#
#               <span class='tag'>购</span>
#           </div>
#           <div class="time" title="2018-07-05 15:22:44">
#             <span title="2018-07-05 15:22:44">2018-07-05</span>
#             <ul class="score-star clearfix" data-score="10">
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
# </ul>
#
#           </div>
#           <div class="operation-comment">
#             <span class="report" data-id="1026981572">举报</span>
#             <div class="approve " data-id="1026981572">
#               <i data-act="comment-approve-click" class="approve-icon"></i><span class="num">29094</span>
#             </div>
#         </div>
#         </div>
#         <div class="comment-content">我认为这是一部跟摔跤吧爸爸同层次的电影，忍到最后还是会流泪。生命很坚强也很脆弱，命与药的关系就是这么赤裸裸。（不良厂商做药设天价，没有良心，不合理，但是这在世界都是完全合法的，决定用这个药来牟取暴利还是济世度人是药商自己的权利，毕竟药是他们研发的。）之前刚看完在这里说不良厂商，还是刚看完有些不清醒了，其实不论他们的主观意愿是什么，都是他们的成果给了病人选择的希望。国家政府会把药纳入医保、发展制度、免除关税来降低病人的压力，我们个人也应该为诸如此类的研发事业做出贡献，比如为医学难题做出重大突破，等等各行各业，才能将未来将好东西做到平价( ¯ᒡ̱¯ )و</div>
#       </div>
#
# <div class="body-mask"></div>
# <div id="report-modal" class="report-modal">
#   <div class="report-modal-container">
#     <div class="modal-header">
#       选择举报原因
#      <img class="close-icon" src="https://p0.meituan.net/ingee/ad871dc016906c0a34ec5f7ae046bd67385.png">
#     </div>
#     <div class="modal-content">
#       <table class="report-label" cellspacing="0">
#         <tr>
#           <td style="margin-right:12px"><span>政治敏感</span></td>
#           <td style="margin-right:12px"><span>暴力恐怖</span></td>
#           <td><span>违法违规</span></td>
#         </tr>
#         <tr>
#           <td style="margin-right:12px"><span>辱骂攻击</span></td>
#           <td style="margin-right:12px"><span>淫秽色情</span></td>
#           <td><span>垃圾广告</span></td>
#         </tr>
#         <tr>
#           <td style="margin-right:12px"><span>盗版抄袭</span></td>
#           <td style="margin-right:12px"><span>涉未成年人</span></td>
#           <td><span>其他</span></td>
#         </tr>
#       </table>
#     </div>
#   </div>
# </div>
#     </li>
#     <li class="comment-container " data-val="{commentid:1026930110}">
#       <div class="portrait-container">
#         <div class="portrait">
#           <img src="https://img.meituan.net/avatar/590edf580b1b58c3e9dc5a8e22061a8e219481.jpg@100w_100h_1e_1c" alt="">
#         </div>
#         <i class="level-2-icon"></i>
#       </div>
#       <div class="main">
#         <div class="main-header clearfix">
#           <div class="user">
#             <span class="name">梦里梦惊梦丶</span>
#
#               <span class='tag'>购</span>
#           </div>
#           <div class="time" title="2018-07-05 02:19:09">
#             <span title="2018-07-05 02:19:09">2018-07-05</span>
#             <ul class="score-star clearfix" data-score="10">
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
# </ul>
#
#           </div>
#           <div class="operation-comment">
#             <span class="report" data-id="1026930110">举报</span>
#             <div class="approve " data-id="1026930110">
#               <i data-act="comment-approve-click" class="approve-icon"></i><span class="num">20748</span>
#             </div>
#         </div>
#         </div>
#         <div class="comment-content">反正我哭了。我妈妈身体也不好。也是药养着。但是现在都有医保啥的。条件也好了。但是身临其境的想下。眼泪就止不住了。很好的电影</div>
#       </div>
#
# <div class="body-mask"></div>
# <div id="report-modal" class="report-modal">
#   <div class="report-modal-container">
#     <div class="modal-header">
#       选择举报原因
#      <img class="close-icon" src="https://p0.meituan.net/ingee/ad871dc016906c0a34ec5f7ae046bd67385.png">
#     </div>
#     <div class="modal-content">
#       <table class="report-label" cellspacing="0">
#         <tr>
#           <td style="margin-right:12px"><span>政治敏感</span></td>
#           <td style="margin-right:12px"><span>暴力恐怖</span></td>
#           <td><span>违法违规</span></td>
#         </tr>
#         <tr>
#           <td style="margin-right:12px"><span>辱骂攻击</span></td>
#           <td style="margin-right:12px"><span>淫秽色情</span></td>
#           <td><span>垃圾广告</span></td>
#         </tr>
#         <tr>
#           <td style="margin-right:12px"><span>盗版抄袭</span></td>
#           <td style="margin-right:12px"><span>涉未成年人</span></td>
#           <td><span>其他</span></td>
#         </tr>
#       </table>
#     </div>
#   </div>
# </div>
#     </li>
#     <li class="comment-container " data-val="{commentid:1026932031}">
#       <div class="portrait-container">
#         <div class="portrait">
#           <img src="https://img.meituan.net/avatar/6809ed6becc04e30e9ddc43cde501a8e70570.jpg@100w_100h_1e_1c" alt="">
#         </div>
#         <i class="level-3-icon"></i>
#       </div>
#       <div class="main">
#         <div class="main-header clearfix">
#           <div class="user">
#             <span class="name">jay20m</span>
#
#               <span class='tag'>购</span>
#           </div>
#           <div class="time" title="2018-07-05 20:16:40">
#             <span title="2018-07-05 20:16:40">2018-07-05</span>
#             <ul class="score-star clearfix" data-score="9">
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right "></i>    </li>
# </ul>
#
#           </div>
#           <div class="operation-comment">
#             <span class="report" data-id="1026932031">举报</span>
#             <div class="approve " data-id="1026932031">
#               <i data-act="comment-approve-click" class="approve-icon"></i><span class="num">8042</span>
#             </div>
#         </div>
#         </div>
#         <div class="comment-content">给九分是因为这片真实的说出了在中国就是吃天价药，发个烧二话不说先打针吊牌几百块就没了，更别说得了重病治疗了，穷人家根本看不起病，
# 法律不在乎人情，只会纵容坏人，好人都得不好报！！</div>
#       </div>
#
# <div class="body-mask"></div>
# <div id="report-modal" class="report-modal">
#   <div class="report-modal-container">
#     <div class="modal-header">
#       选择举报原因
#      <img class="close-icon" src="https://p0.meituan.net/ingee/ad871dc016906c0a34ec5f7ae046bd67385.png">
#     </div>
#     <div class="modal-content">
#       <table class="report-label" cellspacing="0">
#         <tr>
#           <td style="margin-right:12px"><span>政治敏感</span></td>
#           <td style="margin-right:12px"><span>暴力恐怖</span></td>
#           <td><span>违法违规</span></td>
#         </tr>
#         <tr>
#           <td style="margin-right:12px"><span>辱骂攻击</span></td>
#           <td style="margin-right:12px"><span>淫秽色情</span></td>
#           <td><span>垃圾广告</span></td>
#         </tr>
#         <tr>
#           <td style="margin-right:12px"><span>盗版抄袭</span></td>
#           <td style="margin-right:12px"><span>涉未成年人</span></td>
#           <td><span>其他</span></td>
#         </tr>
#       </table>
#     </div>
#   </div>
# </div>
#     </li>
#     <li class="comment-container " data-val="{commentid:1026930189}">
#       <div class="portrait-container">
#         <div class="portrait">
#           <img src="https://img.meituan.net/avatar/da3c32b099a898424055dd802705043d98530.jpg@100w_100h_1e_1c" alt="">
#         </div>
#         <i class="level-2-icon"></i>
#       </div>
#       <div class="main">
#         <div class="main-header clearfix">
#           <div class="user">
#             <span class="name">doggy王</span>
#
#               <span class='tag'>购</span>
#           </div>
#           <div class="time" title="2018-07-22 12:35:18">
#             <span title="2018-07-22 12:35:18">2018-07-22</span>
#             <ul class="score-star clearfix" data-score="10">
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
# </ul>
#
#           </div>
#           <div class="operation-comment">
#             <span class="report" data-id="1026930189">举报</span>
#             <div class="approve " data-id="1026930189">
#               <i data-act="comment-approve-click" class="approve-icon"></i><span class="num">6657</span>
#             </div>
#         </div>
#         </div>
#         <div class="comment-content">据说是一部真实事情而改编的电影，一直觉得徐铮是一位优秀的好演员。
#
# 此部电影反应了社会、现实、人性的一些问题，生命漫长而又短暂，好好活着就是最大的奢侈，好好生活，保持善良。平凡并不可怕，拥有高贵的品格才是人最需要的东西，身处绝境也能绽放出最温暖的笑容。
#
# 这部电影的题材与以往很多国产电影不同，我相信电影最后每一个落泪的人内心都有一份纯净。希望以后能多有这样类型的电影，传递正能量，去正视社会，也敲醒人性的真诚和理解。
#
# 这个世界没有药神，也没有超级英雄，而是因为千千万万平凡如你我的小人物。
#
# 良心剧... 推荐 ～ 🙂🙂🙂</div>
#       </div>
#
# <div class="body-mask"></div>
# <div id="report-modal" class="report-modal">
#   <div class="report-modal-container">
#     <div class="modal-header">
#       选择举报原因
#      <img class="close-icon" src="https://p0.meituan.net/ingee/ad871dc016906c0a34ec5f7ae046bd67385.png">
#     </div>
#     <div class="modal-content">
#       <table class="report-label" cellspacing="0">
#         <tr>
#           <td style="margin-right:12px"><span>政治敏感</span></td>
#           <td style="margin-right:12px"><span>暴力恐怖</span></td>
#           <td><span>违法违规</span></td>
#         </tr>
#         <tr>
#           <td style="margin-right:12px"><span>辱骂攻击</span></td>
#           <td style="margin-right:12px"><span>淫秽色情</span></td>
#           <td><span>垃圾广告</span></td>
#         </tr>
#         <tr>
#           <td style="margin-right:12px"><span>盗版抄袭</span></td>
#           <td style="margin-right:12px"><span>涉未成年人</span></td>
#           <td><span>其他</span></td>
#         </tr>
#       </table>
#     </div>
#   </div>
# </div>
#     </li>
#     <li class="comment-container " data-val="{commentid:1026931225}">
#       <div class="portrait-container">
#         <div class="portrait">
#           <img src="https://img.meituan.net/avatar/f718dd93235b7aa2bc3afae2267ef7dc74370.jpg@100w_100h_1e_1c" alt="">
#         </div>
#         <i class="level-2-icon"></i>
#       </div>
#       <div class="main">
#         <div class="main-header clearfix">
#           <div class="user">
#             <span class="name">生来倔强F</span>
#
#               <span class='tag'>购</span>
#           </div>
#           <div class="time" title="2018-07-05 01:59:04">
#             <span title="2018-07-05 01:59:04">2018-07-05</span>
#             <ul class="score-star clearfix" data-score="10">
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
# </ul>
#
#           </div>
#           <div class="operation-comment">
#             <span class="report" data-id="1026931225">举报</span>
#             <div class="approve " data-id="1026931225">
#               <i data-act="comment-approve-click" class="approve-icon"></i><span class="num">4502</span>
#             </div>
#         </div>
#         </div>
#         <div class="comment-content">不亏和老公凌晨赶场过来看，话不多说，真的值得一看。</div>
#       </div>
#
# <div class="body-mask"></div>
# <div id="report-modal" class="report-modal">
#   <div class="report-modal-container">
#     <div class="modal-header">
#       选择举报原因
#      <img class="close-icon" src="https://p0.meituan.net/ingee/ad871dc016906c0a34ec5f7ae046bd67385.png">
#     </div>
#     <div class="modal-content">
#       <table class="report-label" cellspacing="0">
#         <tr>
#           <td style="margin-right:12px"><span>政治敏感</span></td>
#           <td style="margin-right:12px"><span>暴力恐怖</span></td>
#           <td><span>违法违规</span></td>
#         </tr>
#         <tr>
#           <td style="margin-right:12px"><span>辱骂攻击</span></td>
#           <td style="margin-right:12px"><span>淫秽色情</span></td>
#           <td><span>垃圾广告</span></td>
#         </tr>
#         <tr>
#           <td style="margin-right:12px"><span>盗版抄袭</span></td>
#           <td style="margin-right:12px"><span>涉未成年人</span></td>
#           <td><span>其他</span></td>
#         </tr>
#       </table>
#     </div>
#   </div>
# </div>
#     </li>
#     <li class="comment-container " data-val="{commentid:1026931291}">
#       <div class="portrait-container">
#         <div class="portrait">
#           <img src="https://img.meituan.net/avatar/686db2dec7d3c4746fab08307d25ae6d4231.jpg@100w_100h_1e_1c" alt="">
#         </div>
#         <i class="level-0-icon"></i>
#       </div>
#       <div class="main">
#         <div class="main-header clearfix">
#           <div class="user">
#             <span class="name">乔依</span>
#
#               <span class='tag'>购</span>
#           </div>
#           <div class="time" title="2018-07-05 02:06:05">
#             <span title="2018-07-05 02:06:05">2018-07-05</span>
#             <ul class="score-star clearfix" data-score="10">
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
# </ul>
#
#           </div>
#           <div class="operation-comment">
#             <span class="report" data-id="1026931291">举报</span>
#             <div class="approve " data-id="1026931291">
#               <i data-act="comment-approve-click" class="approve-icon"></i><span class="num">2523</span>
#             </div>
#         </div>
#         </div>
#         <div class="comment-content">真的很赞  笑点泪点把控的很好
# 故事真实    今天去看爆满  前面笑一片  后面哭一片</div>
#       </div>
#
# <div class="body-mask"></div>
# <div id="report-modal" class="report-modal">
#   <div class="report-modal-container">
#     <div class="modal-header">
#       选择举报原因
#      <img class="close-icon" src="https://p0.meituan.net/ingee/ad871dc016906c0a34ec5f7ae046bd67385.png">
#     </div>
#     <div class="modal-content">
#       <table class="report-label" cellspacing="0">
#         <tr>
#           <td style="margin-right:12px"><span>政治敏感</span></td>
#           <td style="margin-right:12px"><span>暴力恐怖</span></td>
#           <td><span>违法违规</span></td>
#         </tr>
#         <tr>
#           <td style="margin-right:12px"><span>辱骂攻击</span></td>
#           <td style="margin-right:12px"><span>淫秽色情</span></td>
#           <td><span>垃圾广告</span></td>
#         </tr>
#         <tr>
#           <td style="margin-right:12px"><span>盗版抄袭</span></td>
#           <td style="margin-right:12px"><span>涉未成年人</span></td>
#           <td><span>其他</span></td>
#         </tr>
#       </table>
#     </div>
#   </div>
# </div>
#     </li>
#     <li class="comment-container " data-val="{commentid:1027433186}">
#       <div class="portrait-container">
#         <div class="portrait">
#           <img src="https://img.meituan.net/avatar/de1fd17ab7490ee050ff46a3e9938c44107518.jpg@100w_100h_1e_1c" alt="">
#         </div>
#         <i class="level-2-icon"></i>
#       </div>
#       <div class="main">
#         <div class="main-header clearfix">
#           <div class="user">
#             <span class="name">刮哥</span>
#
#               <i class="icon cert-person-icon"></i>
#               <span class='tag'>购</span>
#           </div>
#           <div class="time" title="2018-07-07 12:00:16">
#             <span title="2018-07-07 12:00:16">2018-07-07</span>
#             <ul class="score-star clearfix" data-score="9">
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right "></i>    </li>
# </ul>
#
#           </div>
#           <div class="operation-comment">
#             <span class="report" data-id="1027433186">举报</span>
#             <div class="approve " data-id="1027433186">
#               <i data-act="comment-approve-click" class="approve-icon"></i><span class="num">1354</span>
#             </div>
#         </div>
#         </div>
#         <div class="comment-content">虐心，但走心，这是生活的真相。希望越来越好，向有社会责任感的制作团队致敬！</div>
#       </div>
#
# <div class="body-mask"></div>
# <div id="report-modal" class="report-modal">
#   <div class="report-modal-container">
#     <div class="modal-header">
#       选择举报原因
#      <img class="close-icon" src="https://p0.meituan.net/ingee/ad871dc016906c0a34ec5f7ae046bd67385.png">
#     </div>
#     <div class="modal-content">
#       <table class="report-label" cellspacing="0">
#         <tr>
#           <td style="margin-right:12px"><span>政治敏感</span></td>
#           <td style="margin-right:12px"><span>暴力恐怖</span></td>
#           <td><span>违法违规</span></td>
#         </tr>
#         <tr>
#           <td style="margin-right:12px"><span>辱骂攻击</span></td>
#           <td style="margin-right:12px"><span>淫秽色情</span></td>
#           <td><span>垃圾广告</span></td>
#         </tr>
#         <tr>
#           <td style="margin-right:12px"><span>盗版抄袭</span></td>
#           <td style="margin-right:12px"><span>涉未成年人</span></td>
#           <td><span>其他</span></td>
#         </tr>
#       </table>
#     </div>
#   </div>
# </div>
#     </li>
#     <li class="comment-container " data-val="{commentid:1023998101}">
#       <div class="portrait-container">
#         <div class="portrait">
#           <img src="https://img.meituan.net/avatar/a8038e8ff962b4697f2f9e0aa2f7f9be5410.jpg@100w_100h_1e_1c" alt="">
#         </div>
#         <i class="level-1-icon"></i>
#       </div>
#       <div class="main">
#         <div class="main-header clearfix">
#           <div class="user">
#             <span class="name">拾壹鲸落</span>
#
#               <span class='tag'>购</span>
#           </div>
#           <div class="time" title="2018-07-09 12:27:28">
#             <span title="2018-07-09 12:27:28">2018-07-09</span>
#             <ul class="score-star clearfix" data-score="10">
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
# </ul>
#
#           </div>
#           <div class="operation-comment">
#             <span class="report" data-id="1023998101">举报</span>
#             <div class="approve " data-id="1023998101">
#               <i data-act="comment-approve-click" class="approve-icon"></i><span class="num">81</span>
#             </div>
#         </div>
#         </div>
#         <div class="comment-content">期待王传君的演技，就当提前见见关谷吧，丢掉关谷的光环，希望其他角色也能让大家喜欢
# 他只是单纯的不想绑在一个角色里而已，有什么不对，就像苏有朋的五阿哥，赵薇的小燕子，都对他们影响很大，甚至被定型了，跳出这个角色挺好的，人家王传君正经的上海人，大家现在应该都不知道人家正经说话是什么样子吧</div>
#       </div>
#
# <div class="body-mask"></div>
# <div id="report-modal" class="report-modal">
#   <div class="report-modal-container">
#     <div class="modal-header">
#       选择举报原因
#      <img class="close-icon" src="https://p0.meituan.net/ingee/ad871dc016906c0a34ec5f7ae046bd67385.png">
#     </div>
#     <div class="modal-content">
#       <table class="report-label" cellspacing="0">
#         <tr>
#           <td style="margin-right:12px"><span>政治敏感</span></td>
#           <td style="margin-right:12px"><span>暴力恐怖</span></td>
#           <td><span>违法违规</span></td>
#         </tr>
#         <tr>
#           <td style="margin-right:12px"><span>辱骂攻击</span></td>
#           <td style="margin-right:12px"><span>淫秽色情</span></td>
#           <td><span>垃圾广告</span></td>
#         </tr>
#         <tr>
#           <td style="margin-right:12px"><span>盗版抄袭</span></td>
#           <td style="margin-right:12px"><span>涉未成年人</span></td>
#           <td><span>其他</span></td>
#         </tr>
#       </table>
#     </div>
#   </div>
# </div>
#     </li>
#     <li class="comment-container " data-val="{commentid:1029977800}">
#       <div class="portrait-container">
#         <div class="portrait">
#           <img src="https://img.meituan.net/avatar/78e917917cd6d89270cdd1ea2095de31176810.jpg@100w_100h_1e_1c" alt="">
#         </div>
#         <i class="level-2-icon"></i>
#       </div>
#       <div class="main">
#         <div class="main-header clearfix">
#           <div class="user">
#             <span class="name">浓雾号角</span>
#
#               <i class="icon cert-person-icon"></i>
#               <span class='tag'>购</span>
#           </div>
#           <div class="time" title="2018-07-19 22:42:14">
#             <span title="2018-07-19 22:42:14">2018-07-19</span>
#             <ul class="score-star clearfix" data-score="10">
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
# </ul>
#
#           </div>
#           <div class="operation-comment">
#             <span class="report" data-id="1029977800">举报</span>
#             <div class="approve " data-id="1029977800">
#               <i data-act="comment-approve-click" class="approve-icon"></i><span class="num">47</span>
#             </div>
#         </div>
#         </div>
#         <div class="comment-content">私以为，能够成为经典的艺术作品大致分为四种：
# 第一种，(其情节或台词等)对过往或者历史有记录，回顾，反思之用
# (如《现代启示录》《辛德勒名单》)
# 第二种，(其情节或台词等)具有强大现实意义，对现世情状构成了反思或者推动
# (《药神》属于这一类)
# 第三种，(其情节或台词等)对人类世界、物质文明等未来生活进行思考和尝试性的揭示
# (如《2001太空漫游》)
# 第四种，(其情节或台词等)给人以极致美的体验，这种美包括但不仅限于画面和特效，也包括一种情感之美，生命之美，诗学美感，人类信仰之美等。
# (如《泰坦尼克号》《断背山》等)
# 不属于这四类的都不能称之为艺术。
#
# 由衷的希望国内多一些这样的艺术作品。</div>
#       </div>
#
# <div class="body-mask"></div>
# <div id="report-modal" class="report-modal">
#   <div class="report-modal-container">
#     <div class="modal-header">
#       选择举报原因
#      <img class="close-icon" src="https://p0.meituan.net/ingee/ad871dc016906c0a34ec5f7ae046bd67385.png">
#     </div>
#     <div class="modal-content">
#       <table class="report-label" cellspacing="0">
#         <tr>
#           <td style="margin-right:12px"><span>政治敏感</span></td>
#           <td style="margin-right:12px"><span>暴力恐怖</span></td>
#           <td><span>违法违规</span></td>
#         </tr>
#         <tr>
#           <td style="margin-right:12px"><span>辱骂攻击</span></td>
#           <td style="margin-right:12px"><span>淫秽色情</span></td>
#           <td><span>垃圾广告</span></td>
#         </tr>
#         <tr>
#           <td style="margin-right:12px"><span>盗版抄袭</span></td>
#           <td style="margin-right:12px"><span>涉未成年人</span></td>
#           <td><span>其他</span></td>
#         </tr>
#       </table>
#     </div>
#   </div>
# </div>
#     </li>
#     <li class="comment-container last" data-val="{commentid:1028781737}">
#       <div class="portrait-container">
#         <div class="portrait">
#           <img src="https://img.meituan.net/avatar/42dc3e8bb7c9b37c6b00db600a05597c232333.jpg@100w_100h_1e_1c" alt="">
#         </div>
#         <i class="level-3-icon"></i>
#       </div>
#       <div class="main">
#         <div class="main-header clearfix">
#           <div class="user">
#             <span class="name">莎草</span>
#
#               <i class="icon cert-person-icon"></i>
#               <span class='tag'>购</span>
#           </div>
#           <div class="time" title="2018-07-13 00:38:10">
#             <span title="2018-07-13 00:38:10">2018-07-13</span>
#             <ul class="score-star clearfix" data-score="9">
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right active"></i>    </li>
#     <li>
# <i class="half-star left active"></i><i class="half-star right "></i>    </li>
# </ul>
#
#           </div>
#           <div class="operation-comment">
#             <span class="report" data-id="1028781737">举报</span>
#             <div class="approve " data-id="1028781737">
#               <i data-act="comment-approve-click" class="approve-icon"></i><span class="num">105</span>
#             </div>
#         </div>
#         </div>
#         <div class="comment-content">虽然现实远比这残酷，影片进行了文艺化处理，但仍然值得深思，不失为一部好片。徐峥是一个有自己想法的演员和导演，不随波逐流，才能走得更远。</div>
#       </div>
#
# <div class="body-mask"></div>
# <div id="report-modal" class="report-modal">
#   <div class="report-modal-container">
#     <div class="modal-header">
#       选择举报原因
#      <img class="close-icon" src="https://p0.meituan.net/ingee/ad871dc016906c0a34ec5f7ae046bd67385.png">
#     </div>
#     <div class="modal-content">
#       <table class="report-label" cellspacing="0">
#         <tr>
#           <td style="margin-right:12px"><span>政治敏感</span></td>
#           <td style="margin-right:12px"><span>暴力恐怖</span></td>
#           <td><span>违法违规</span></td>
#         </tr>
#         <tr>
#           <td style="margin-right:12px"><span>辱骂攻击</span></td>
#           <td style="margin-right:12px"><span>淫秽色情</span></td>
#           <td><span>垃圾广告</span></td>
#         </tr>
#         <tr>
#           <td style="margin-right:12px"><span>盗版抄袭</span></td>
#           <td style="margin-right:12px"><span>涉未成年人</span></td>
#           <td><span>其他</span></td>
#         </tr>
#       </table>
#     </div>
#   </div>
# </div>
#     </li>
# </ul>
#             </div>
#               <a class="comment-entry" data-act="comment-no-content-click">写短评</a>
#
#     </div>
#   </div>
#
#   <div class="module">
#     <div class="mod-title">
#       <h2>影片资料</h2>
#     </div>
#     <div class="mod-content">
#                     <div class="attribute">
#                   <div class="attribute-item">
#                     <div class="attribute-item-top">
#                       <img class="attribute-item-icon" src="https://p0.meituan.net/mmdb/250a17bc199c0b942073bec5429d2f422175.png@14w_14h_1e_1c" />
#                       <span class="attribute-item-title">家长引导</span>
#                     </div>
#                     <div class="attribute-item-content ellipsis">本片在中国香港的评级为【IIA】，未满16岁的儿童不宜观看。</div>
#                   </div>
#                   <div class="attribute-item">
#                     <div class="attribute-item-top">
#                       <img class="attribute-item-icon" src="https://p0.meituan.net/mmdb/1764aeeb280e07c55b861481cc717e2c1511.png@14w_14h_1e_1c" />
#                       <span class="attribute-item-title">出品发行</span>
#                     </div>
#                     <div class="attribute-item-content ellipsis">霍尔果斯坏猴子影视文化传播有限公司</div>
#                   </div>
#                   <div class="attribute-item">
#                     <div class="attribute-item-top">
#                       <img class="attribute-item-icon" src="https://p0.meituan.net/mmdb/c694fd8f82f4e706e5318a5175265b552010.png@14w_14h_1e_1c" />
#                       <span class="attribute-item-title">技术参数</span>
#                     </div>
#                     <div class="attribute-item-content ellipsis">1小时57分钟</div>
#                   </div>
#               </div>
#
#     </div>
#   </div>
#
#   <div class="module">
#     <div class="mod-title">
#       <h2>荣誉奖项</h2>
#     </div>
#     <div class="mod-content">
#                       <div class="film-honors">
# ...
#           <img data-src="https://p0.meituan.net/mmdb/d1593b7d6b09d8016767711ce7a784848004096.jpg@106w_145h_1e_1c" alt="长津湖之水门桥海报封面" />
#         </div>
#       </a>
#       <div class="movie-ver"></div>
#       <div class="movie-item-hover">
#         <a href="/films/1446115" target="_blank" data-act="movie-click" data-val="{movieid:1446115}">
#            <img class="movie-hover-img" src="https://p0.meituan.net/mmdb/d1593b7d6b09d8016767711ce7a784848004096.jpg@218w_300h_1e_1c" alt="长津湖之水门桥" />
#           <div class="movie-hover-info">
#             <div class="movie-hover-title" title="长津湖之水门桥" >
#               <span class="name noscore">长津湖之水门桥</span>
#             </div>
#             <div class="movie-hover-title" title="长津湖之水门桥" >
#               <span class="hover-tag">类型:</span>
#               剧情／历史／战争
#             </div>
#             <div class="movie-hover-title" title="长津湖之水门桥" >
#               <span class="hover-tag">主演:</span>
#               吴京／易烊千玺／朱亚文
#             </div>
#             <div class="movie-hover-title movie-hover-brief" title="长津湖之水门桥" >
#               <span class="hover-tag">上映时间:</span>
#               2022
#             </div>
#           </div>
#         </a>
#       </div>
#     </div>
#
#     <div class="channel-detail movie-item-title" title="长津湖之水门桥">
#       <a href="/films/1446115" target="_blank" data-act="movies-click" data-val="{movieId:1446115}">长津湖之水门桥</a>
#     </div>
# <div class="channel-detail channel-detail-orange">暂无评分</div>
#
#   <dd>
#     <div class="movie-item film-channel">
#       <a href="/films/1363244" target="_blank" data-act="movie-click" data-val="{movieid:1363244}">
#         <div class="movie-poster">
#           <img class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png" />
#           <img data-src="https://p0.meituan.net/mmdb/e8c6fc39ad774426b8ccfc33b22dc722185055.jpg@106w_145h_1e_1c" alt="铁道英雄海报封面" />
#         </div>
#       </a>
#       <div class="movie-ver"></div>
#       <div class="movie-item-hover">
#         <a href="/films/1363244" target="_blank" data-act="movie-click" data-val="{movieid:1363244}">
#            <img class="movie-hover-img" src="https://p0.meituan.net/mmdb/e8c6fc39ad774426b8ccfc33b22dc722185055.jpg@218w_300h_1e_1c" alt="铁道英雄" />
#           <div class="movie-hover-info">
#             <div class="movie-hover-title" title="铁道英雄" >
#               <span class="name noscore">铁道英雄</span>
#             </div>
#             <div class="movie-hover-title" title="铁道英雄" >
#               <span class="hover-tag">类型:</span>
#               战争／剧情／动作
#             </div>
#             <div class="movie-hover-title" title="铁道英雄" >
#               <span class="hover-tag">主演:</span>
#               张涵予／范伟／魏晨
#             </div>
#             <div class="movie-hover-title movie-hover-brief" title="铁道英雄" >
#               <span class="hover-tag">上映时间:</span>
#               2021-11-19
#             </div>
#           </div>
#         </a>
#       </div>
#     </div>
#
#     <div class="channel-detail movie-item-title" title="铁道英雄">
#       <a href="/films/1363244" target="_blank" data-act="movies-click" data-val="{movieId:1363244}">铁道英雄</a>
#     </div>
# <div class="channel-detail channel-detail-orange">暂无评分</div>
#
#   <dd>
#     <div class="movie-item film-channel">
#       <a href="/films/1397410" target="_blank" data-act="movie-click" data-val="{movieid:1397410}">
#         <div class="movie-poster">
#           <img class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png" />
#           <img data-src="https://p0.meituan.net/movie/f8c01c7e740a0b9bbeb7979d239766774138881.jpg@106w_145h_1e_1c" alt="石狮爱情故事海报封面" />
#         </div>
#       </a>
#       <div class="movie-ver"></div>
#       <div class="movie-item-hover">
#         <a href="/films/1397410" target="_blank" data-act="movie-click" data-val="{movieid:1397410}">
#            <img class="movie-hover-img" src="https://p0.meituan.net/movie/f8c01c7e740a0b9bbeb7979d239766774138881.jpg@218w_300h_1e_1c" alt="石狮爱情故事" />
#           <div class="movie-hover-info">
#             <div class="movie-hover-title" title="石狮爱情故事" >
#               <span class="name noscore">石狮爱情故事</span>
#             </div>
#             <div class="movie-hover-title" title="石狮爱情故事" >
#               <span class="hover-tag">类型:</span>
#               爱情／战争
#             </div>
#             <div class="movie-hover-title" title="石狮爱情故事" >
#               <span class="hover-tag">主演:</span>
#               龚秋子／陈清奇／王晶晶
#             </div>
#             <div class="movie-hover-title movie-hover-brief" title="石狮爱情故事" >
#               <span class="hover-tag">上映时间:</span>
#               2021-11-11
#             </div>
#           </div>
#         </a>
#       </div>
#     </div>
#
#     <div class="channel-detail movie-item-title" title="石狮爱情故事">
#       <a href="/films/1397410" target="_blank" data-act="movies-click" data-val="{movieId:1397410}">石狮爱情故事</a>
#     </div>
# <div class="channel-detail channel-detail-orange">暂无评分</div>
#
#   <dd>
#     <div class="movie-item film-channel">
#       <a href="/films/257706" target="_blank" data-act="movie-click" data-val="{movieid:257706}">
#         <div class="movie-poster">
#           <img class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png" />
#           <img data-src="https://p0.meituan.net/movie/0e81560dc9910a6a658a82ec7a054ceb5075992.jpg@106w_145h_1e_1c" alt="长津湖海报封面" />
#         </div>
#       </a>
#       <div class="movie-ver"><i class="imax2d"></i></div>
#       <div class="movie-item-hover">
#         <a href="/films/257706" target="_blank" data-act="movie-click" data-val="{movieid:257706}">
#            <img class="movie-hover-img" src="https://p0.meituan.net/movie/0e81560dc9910a6a658a82ec7a054ceb5075992.jpg@218w_300h_1e_1c" alt="长津湖" />
#           <div class="movie-hover-info">
#             <div class="movie-hover-title" title="长津湖" >
#               <span class="name ">长津湖</span>
#                 <span class="score channel-detail-orange"><i class="integer">9.</i><i class="fraction">5</i></span>
#             </div>
#             <div class="movie-hover-title" title="长津湖" >
#               <span class="hover-tag">类型:</span>
#               剧情／历史／战争
#             </div>
#             <div class="movie-hover-title" title="长津湖" >
#               <span class="hover-tag">主演:</span>
#               吴京／易烊千玺／段奕宏
#             </div>
#             <div class="movie-hover-title movie-hover-brief" title="长津湖" >
#               <span class="hover-tag">上映时间:</span>
#               2021-09-30
#             </div>
#           </div>
#         </a>
#       </div>
#     </div>
#
#     <div class="channel-detail movie-item-title" title="长津湖">
#       <a href="/films/257706" target="_blank" data-act="movies-click" data-val="{movieId:257706}">长津湖</a>
#     </div>
# <div class="channel-detail channel-detail-orange"><i class="integer">9.</i><i class="fraction">5</i></div>
#
#   <dd>
#     <div class="movie-item film-channel">
#       <a href="/films/344264" target="_blank" data-act="movie-click" data-val="{movieid:344264}">
#         <div class="movie-poster">
#           <img class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png" />
#           <img data-src="https://p0.meituan.net/movie/0355f74de087b699b85b7daa3d7881ec365712.jpg@106w_145h_1e_1c" alt="战狼2海报封面" />
#         </div>
#       </a>
#       <div class="movie-ver"><i class="imax2d"></i></div>
#       <div class="movie-item-hover">
#         <a href="/films/344264" target="_blank" data-act="movie-click" data-val="{movieid:344264}">
#            <img class="movie-hover-img" src="https://p0.meituan.net/movie/0355f74de087b699b85b7daa3d7881ec365712.jpg@218w_300h_1e_1c" alt="战狼2" />
#           <div class="movie-hover-info">
#             <div class="movie-hover-title" title="战狼2" >
#               <span class="name ">战狼2</span>
#                 <span class="score channel-detail-orange"><i class="integer">9.</i><i class="fraction">7</i></span>
#             </div>
#             <div class="movie-hover-title" title="战狼2" >
#               <span class="hover-tag">类型:</span>
#               动作／战争
#             </div>
#             <div class="movie-hover-title" title="战狼2" >
#               <span class="hover-tag">主演:</span>
#               吴京／弗兰克·格里罗／吴刚
#             </div>
#             <div class="movie-hover-title movie-hover-brief" title="战狼2" >
#               <span class="hover-tag">上映时间:</span>
#               2017-07-27
#             </div>
#           </div>
#         </a>
#       </div>
#     </div>
#
#     <div class="channel-detail movie-item-title" title="战狼2">
#       <a href="/films/344264" target="_blank" data-act="movies-click" data-val="{movieId:344264}">战狼2</a>
#     </div>
# <div class="channel-detail channel-detail-orange"><i class="integer">9.</i><i class="fraction">7</i></div>
#
#   <dd>
#     <div class="movie-item film-channel">
#       <a href="/films/1339160" target="_blank" data-act="movie-click" data-val="{movieid:1339160}">
#         <div class="movie-poster">
#           <img class="poster-default" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/image/loading_2.e3d934bf.png" />
#           <img data-src="https://p1.meituan.net/moviemachine/5cbf9a626b7ed27c96ca3c748655b3ec2550103.jpg@106w_145h_1e_1c" alt="金刚川海报封面" />
#         </div>
#       </a>
#       <div class="movie-ver"><i class="imax2d"></i></div>
#       <div class="movie-item-hover">
#         <a href="/films/1339160" target="_blank" data-act="movie-click" data-val="{movieid:1339160}">
#            <img class="movie-hover-img" src="https://p1.meituan.net/moviemachine/5cbf9a626b7ed27c96ca3c748655b3ec2550103.jpg@218w_300h_1e_1c" alt="金刚川" />
#           <div class="movie-hover-info">
#             <div class="movie-hover-title" title="金刚川" >
#               <span class="name ">金刚川</span>
#                 <span class="score channel-detail-orange"><i class="integer">9.</i><i class="fraction">4</i></span>
#             </div>
#             <div class="movie-hover-title" title="金刚川" >
#               <span class="hover-tag">类型:</span>
#               战争／剧情／历史
#             </div>
#             <div class="movie-hover-title" title="金刚川" >
#               <span class="hover-tag">主演:</span>
#               张译／吴京／李九霄
#             </div>
#             <div class="movie-hover-title movie-hover-brief" title="金刚川" >
#               <span class="hover-tag">上映时间:</span>
#               2020-10-23
#             </div>
#           </div>
#         </a>
#       </div>
#     </div>
#
#     <div class="channel-detail movie-item-title" title="金刚川">
#       <a href="/films/1339160" target="_blank" data-act="movies-click" data-val="{movieId:1339160}">金刚川</a>
#     </div>
# <div class="channel-detail channel-detail-orange"><i class="integer">9.</i><i class="fraction">4</i></div>
#
# </dl>
#
# </div>
#
#
#     </div>
#   </div>
#     </div>
#   </div>
# </div>
# <script id="comment-form-container" type="text/template">
#   <form id="comment-form" data-val="{movieid:1303}">
#     <div class="score-msg-container ">
#         <div class="score"><span class="num"></span>分</div>
#         <div class="score-message"></div>
#         <div class="no-score">
#           请点击星星评分
#         </div>
#     </div>
#     <div class="score-star-contaienr">
#       <ul class="score-star clearfix" data-score="">
#     <li>
# <i class="half-star left "></i><i class="half-star right "></i>    </li>
#     <li>
# <i class="half-star left "></i><i class="half-star right "></i>    </li>
#     <li>
# <i class="half-star left "></i><i class="half-star right "></i>    </li>
#     <li>
# <i class="half-star left "></i><i class="half-star right "></i>    </li>
#     <li>
# <i class="half-star left "></i><i class="half-star right "></i>    </li>
# </ul>
#
#     </div>
#     <div class="content-container">
#       <textarea placeholder="快来说说你的看法吧" name="content" id="" cols="30" rows="10"></textarea>
#       <span class="word-count-info"></span>
#     </div>
#     <input type="hidden" name="score" />
#     <input class="btn" type="submit" value="提交" data-act="comment-submit-click" />
#   </form>
#   <div class="close">×</div>
# </script>
#     </div>
#
# <div class="footer">
#   <p class="friendly-links">
#     关于猫眼 :
#     <a href="http://ir.maoyan.com/s/index.php#pageScroll0" target="_blank">关于我们</a>
#     <span></span>
#     <a href="http://ir.maoyan.com/s/index.php#pageScroll1" target="_blank">管理团队</a>
#     <span></span>
#     <a href="http://ir.maoyan.com/s/index.php#pageScroll2" target="_blank">投资者关系</a>
#     &nbsp;&nbsp;&nbsp;&nbsp;
#     友情链接 :
#     <a href="http://www.meituan.com" data-query="utm_source=wwwmaoyan" target="_blank">美团网</a>
#     <span></span>
#     <a href="http://www.gewara.com" data-query="utm_source=wwwmaoyan">格瓦拉</a>
#     <span></span>
#     <a href="http://i.meituan.com/client" data-query="utm_source=wwwmaoyan" target="_blank">美团下载</a>
#     <span></span>
#     <a href="https://www.huanxi.com" data-query="utm_source=maoyan_pc" target="_blank">欢喜首映</a>
#   </p>
#   <p class="friendly-links">
#     商务合作邮箱：v@maoyan.com
#     客服电话：10105335
#     违法和不良信息/涉未成年人有害信息举报电话：4006018900
#   </p>
#   <p class="friendly-links">
#     用户举报/涉未成年人有害信息举报邮箱：tousujubao@meituan.com
#     舞弊线索举报邮箱：wubijubao@maoyan.com
#   </p>
#   <p class="friendly-links  credentials">
#     <a href="/about/licence/1" target="_blank">中华人民共和国增值电信业务经营许可证 京B2-20190350</a>
#     <span></span>
#     <a href="/about/licence/4" target="_blank">营业性演出许可证 京演（机构）（2019）4094号</a>
#   </p>
#   <p class="friendly-links  credentials">
#     <a href="/about/licence/3" target="_blank">广播电视节目制作经营许可证 （京）字第08478号</a>
#     <span></span>
#     <a href="/about/licence/2" target="_blank">网络文化经营许可证 京网文（2019）3837-369号 </a>
#   </p>
#   <p class="friendly-links  credentials">
#     <a href="/rules/agreement" target="_blank">猫眼用户服务协议 </a>
#     <span></span>
#     <a href="/rules/rule" target="_blank">猫眼平台交易规则总则 </a>
#     <span></span>
#     <a href="/rules/privacy" target="_blank">隐私政策 </a>
#   </p>
#   <p class="friendly-links  credentials">
#     <a href="http://www.beian.gov.cn/portal/registerSystemInfo?recordcode=11010102003232" target="_blank">京公网安备
#       11010102003232号</a>
#     <span></span>
#     <a href="http://beian.miit.gov.cn/" target="_blank">京ICP备16022489号-1</a>
#   </p>
#   <p>北京猫眼文化传媒有限公司</p>
#   <p>
#     &copy;<span class="my-footer-year">2016</span>
#     猫眼电影 www.maoyan.com</p>
#   <div class="certificate">
#     <a href="http://sq.ccm.gov.cn:80/ccnt/sczr/service/business/emark/toDetail/350CF8BCA8416C4FE0530140A8C0957E"
#       target="_blank">
#       <img src="https://p0.meituan.net/moviemachine/e54374ccf134d1f7b2c5b075a74fca525326.png" />
#     </a>
#     <a href="/about/licence/5" target="_blank">
#       <img src="https://p1.meituan.net/moviemachine/805f605d5cf1b1a02a4e3a5e29df003b8376.png" />
#     </a>
#     <a href="https://www.12377.cn" target="_blank">
#       <img src="https://p0.meituan.net/scarlett/3cd2a9b7dc179531d20d27a5fd686e783787.png" />
#     </a>
#   </div>
# </div>
#
#     <script crossorigin="anonymous" src="//www.dpfile.com/app/owl/static/owl_1.7.11.js"></script>
#     <script>
#       Owl.start({
#         project: 'com.sankuai.movie.fe.mywww',
#         pageUrl: location.href.split('?')[0].replace(/\/\d+/g, '/:id'),
#         devMode: false
#       })
#     </script>
#     <!--[if IE 8]><script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/es5-shim.bbad933f.js"></script><![endif]-->
#     <!--[if IE 8]><script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/es5-sham.d6ea26f4.js"></script><![endif]-->
#     <script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/common.850e1cac.js"></script>
# <script crossorigin="anonymous" src="//s3plus.meituan.net/v1/mss_e2821d7f0cfe4ac1bf9202ecf9590e67/cdn-prod/file:5788b470/movie-detail.46707f6f.js"></script>
# </body>
# </html>

# %%
#df = pd.DataFrame(all_info) #将获取到的所有数据生成表格
##设置下边表格的字段
#df.columns = ['名称', '演员', '导演', '类型','上架时间']

# %%
#df

# %%
#df.to_csv('测试.csv',encoding='utf_8_sig')

# %%
#df
